# %% [markdown]
# # Trends of Power Outages
#
# **Name(s)**: Anirudh Indraganti (A16032124)
#
# **Website Link**: https://aindragaofficial.github.io/PowerOutageAnalysis/

# %% [markdown]
# Question: Are there similar amount of power outages across different regions?

# %% [markdown]
# ## Code

# %%
import pandas as pd
import numpy as np
import os
import folium
import geopandas as gpd
import plotly.express as px
pd.options.plotting.backend = 'plotly'

# %% [markdown]
# ### Data Cleaning

# %%
power_outages_df = pd.read_excel('outage.xlsx', header=5)
power_outages_df.head()
# Out:
#   variables  OBS    YEAR  MONTH U.S._STATE POSTAL.CODE NERC.REGION  \
# 0     Units  NaN     NaN    NaN        NaN         NaN         NaN
# 1       NaN  1.0  2011.0    7.0  Minnesota          MN         MRO
# 2       NaN  2.0  2014.0    5.0  Minnesota          MN         MRO
# 3       NaN  3.0  2010.0   10.0  Minnesota          MN         MRO
# 4       NaN  4.0  2012.0    6.0  Minnesota          MN         MRO
#
#        CLIMATE.REGION ANOMALY.LEVEL CLIMATE.CATEGORY  ... POPPCT_URBAN  \
# 0                 NaN       numeric              NaN  ...            %
# 1  East North Central          -0.3           normal  ...        73.27
# 2  East North Central          -0.1           normal  ...        73.27
# 3  East North Central          -1.5             cold  ...        73.27
# 4  East North Central          -0.1           normal  ...        73.27
#
#   POPPCT_UC             POPDEN_URBAN                POPDEN_UC  \
# 0         %  persons per square mile  persons per square mile
# 1     15.28                     2279                   1700.5
# 2     15.28                     2279                   1700.5
# 3     15.28                     2279                   1700.5
# 4     15.28                     2279                   1700.5
#
#               POPDEN_RURAL AREAPCT_URBAN AREAPCT_UC   PCT_LAND PCT_WATER_TOT  \
# 0  persons per square mile             %          %          %             %
# 1                     18.2          2.14        0.6  91.592666      8.407334
# 2                     18.2          2.14        0.6  91.592666      8.407334
# 3                     18.2          2.14        0.6  91.592666      8.407334
# 4                     18.2          2.14        0.6  91.592666      8.407334
#
#    PCT_WATER_INLAND
# 0                 %
# 1          5.478743
# 2          5.478743
# 3          5.478743
# 4          5.478743
#
# [5 rows x 57 columns]

# %%
power_outages_df.drop(['variables', 'OBS'], axis=1, inplace=True)
power_outages_df.drop(0, inplace=True)
print(power_outages_df.shape)
power_outages_df.head()
# Out:
# (1534, 55)
#      YEAR  MONTH U.S._STATE POSTAL.CODE NERC.REGION      CLIMATE.REGION  \
# 1  2011.0    7.0  Minnesota          MN         MRO  East North Central
# 2  2014.0    5.0  Minnesota          MN         MRO  East North Central
# 3  2010.0   10.0  Minnesota          MN         MRO  East North Central
# 4  2012.0    6.0  Minnesota          MN         MRO  East North Central
# 5  2015.0    7.0  Minnesota          MN         MRO  East North Central
#
#   ANOMALY.LEVEL CLIMATE.CATEGORY    OUTAGE.START.DATE OUTAGE.START.TIME  ...  \
# 1          -0.3           normal  2011-07-01 00:00:00          17:00:00  ...
# 2          -0.1           normal  2014-05-11 00:00:00          18:38:00  ...
# 3          -1.5             cold  2010-10-26 00:00:00          20:00:00  ...
# 4          -0.1           normal  2012-06-19 00:00:00          04:30:00  ...
# 5           1.2             warm  2015-07-18 00:00:00          02:00:00  ...
#
#   POPPCT_URBAN POPPCT_UC POPDEN_URBAN POPDEN_UC POPDEN_RURAL AREAPCT_URBAN  \
# 1        73.27     15.28         2279    1700.5         18.2          2.14
# 2        73.27     15.28         2279    1700.5         18.2          2.14
# 3        73.27     15.28         2279    1700.5         18.2          2.14
# 4        73.27     15.28         2279    1700.5         18.2          2.14
# 5        73.27     15.28         2279    1700.5         18.2          2.14
#
#   AREAPCT_UC   PCT_LAND PCT_WATER_TOT PCT_WATER_INLAND
# 1        0.6  91.592666      8.407334         5.478743
# 2        0.6  91.592666      8.407334         5.478743
# 3        0.6  91.592666      8.407334         5.478743
# 4        0.6  91.592666      8.407334         5.478743
# 5        0.6  91.592666      8.407334         5.478743
#
# [5 rows x 55 columns]

# %%
clean_power_outages_df = power_outages_df.assign(
    **{
        'OUTAGE.START.TIME': pd.to_datetime(power_outages_df['OUTAGE.START.DATE']) + pd.to_timedelta(power_outages_df['OUTAGE.START.TIME'].astype(str, errors='ignore')),
        'OUTAGE.RESTORATION.TIME': pd.to_datetime(power_outages_df['OUTAGE.RESTORATION.DATE']) + pd.to_timedelta(power_outages_df['OUTAGE.RESTORATION.TIME'].astype(str, errors='ignore')),
        'OUTAGE.DURATION': power_outages_df['OUTAGE.DURATION'] / 60
    }
).drop(['OUTAGE.START.DATE', 'OUTAGE.RESTORATION.DATE'], axis=1, inplace=False)

clean_power_outages_df.reset_index(inplace=True)
not_drop_cols = [
    'U.S._STATE', 'POSTAL.CODE', 'NERC.REGION', 'CLIMATE.REGION', 'ANOMALY.LEVEL', 'OUTAGE.START.TIME',\
    'OUTAGE.RESTORATION.TIME', 'OUTAGE.DURATION', 'DEMAND.LOSS.MW', 'CUSTOMERS.AFFECTED', 'RES.CUSTOMERS',\
    'COM.CUSTOMERS', 'IND.CUSTOMERS', 'TOTAL.CUSTOMERS', 'CAUSE.CATEGORY'
 ]
clean_power_outages_df.drop(clean_power_outages_df.columns.difference(not_drop_cols), axis=1, inplace=True)
clean_power_outages_df.head()
# Out:
#   U.S._STATE POSTAL.CODE NERC.REGION      CLIMATE.REGION ANOMALY.LEVEL  \
# 0  Minnesota          MN         MRO  East North Central          -0.3
# 1  Minnesota          MN         MRO  East North Central          -0.1
# 2  Minnesota          MN         MRO  East North Central          -1.5
# 3  Minnesota          MN         MRO  East North Central          -0.1
# 4  Minnesota          MN         MRO  East North Central           1.2
#
#     OUTAGE.START.TIME OUTAGE.RESTORATION.TIME      CAUSE.CATEGORY  \
# 0 2011-07-01 17:00:00     2011-07-03 20:00:00      severe weather
# 1 2014-05-11 18:38:00     2014-05-11 18:39:00  intentional attack
# 2 2010-10-26 20:00:00     2010-10-28 22:00:00      severe weather
# 3 2012-06-19 04:30:00     2012-06-20 23:00:00      severe weather
# 4 2015-07-18 02:00:00     2015-07-19 07:00:00      severe weather
#
#   OUTAGE.DURATION DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  RES.CUSTOMERS  \
# 0            51.0            NaN             70000.0      2308736.0
# 1        0.016667            NaN                 NaN      2345860.0
# 2            50.0            NaN             70000.0      2300291.0
# 3            42.5            NaN             68200.0      2317336.0
# 4            29.0            250            250000.0      2374674.0
#
#    COM.CUSTOMERS  IND.CUSTOMERS  TOTAL.CUSTOMERS
# 0       276286.0        10673.0        2595696.0
# 1       284978.0         9898.0        2640737.0
# 2       276463.0        10150.0        2586905.0
# 3       278466.0        11010.0        2606813.0
# 4       289044.0         9812.0        2673531.0

# %% [markdown]
# ## Univariate Analysis

# %%
fig = px.histogram(clean_power_outages_df, x='OUTAGE.DURATION')
fig

# %%
px.histogram(clean_power_outages_df, x='DEMAND.LOSS.MW')

# %% [markdown]
# ## Bivariate Analysis

# %%
geojson_data = gpd.read_file('usa_map.json')
geojson_data.head()
# Out:
#    id        name                                           geometry
# 0  AL     Alabama  POLYGON ((-87.35930 35.00118, -85.60667 34.984...
# 1  AK      Alaska  MULTIPOLYGON (((-131.60202 55.11798, -131.5691...
# 2  AZ     Arizona  POLYGON ((-109.04250 37.00026, -109.04798 31.3...
# 3  AR    Arkansas  POLYGON ((-94.47384 36.50186, -90.15254 36.496...
# 4  CA  California  POLYGON ((-123.23326 42.00619, -122.37885 42.0...

# %%
avg_outage_durations = clean_power_outages_df.groupby('U.S._STATE')['OUTAGE.DURATION'].mean().to_frame().reset_index(inplace=False)
avg_outage_durations.head()
# Out:
#    U.S._STATE  OUTAGE.DURATION
# 0     Alabama        19.213333
# 1      Alaska              NaN
# 2     Arizona        75.882000
# 3    Arkansas        25.239333
# 4  California        27.772306

# %%
usa_map = folium.Map(location=[40, -95], zoom_start=4)
folium.Choropleth(
    geo_data=geojson_data,
    data=avg_outage_durations,
    columns=['U.S._STATE', 'OUTAGE.DURATION'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Average Outage Duration',
).add_to(usa_map)

folium.LayerControl().add_to(usa_map)
usa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d037c3d0dd0c497c239de9fcea8fd501 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d037c3d0dd0c497c239de9fcea8fd501&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d037c3d0dd0c497c239de9fcea8fd501 = L.map(
#                 &quot;map_d037c3d0dd0c497c239de9fcea8fd501&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44a35872767bf03e515a7eb6488cb8ae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d037c3d0dd0c497c239de9fcea8fd501);
#
#
#             var choropleth_2e18bf757ee9f010f5e59f09780307b9 = L.featureGroup(
#                 {}
#             ).addTo(map_d037c3d0dd0c497c239de9fcea8fd501);
#
#
#         function geo_json_669234622ce7d9c155ea564ab4094f04_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;38&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;8&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;4&quot;: case &quot;9&quot;: case &quot;12&quot;: case &quot;19&quot;: case &quot;26&quot;: case &quot;32&quot;: case &quot;46&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;13&quot;: case &quot;22&quot;: case &quot;24&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;37&quot;: case &quot;39&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;21&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;47&quot;: case &quot;48&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_669234622ce7d9c155ea564ab4094f04_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_669234622ce7d9c155ea564ab4094f04 = L.geoJson(null, {
#                 onEachFeature: geo_json_669234622ce7d9c155ea564ab4094f04_onEachFeature,
#
#                 style: geo_json_669234622ce7d9c155ea564ab4094f04_styler,
#         });
#
#         function geo_json_669234622ce7d9c155ea564ab4094f04_add (data) {
#             geo_json_669234622ce7d9c155ea564ab4094f04
#                 .addData(data)
#                 .addTo(choropleth_2e18bf757ee9f010f5e59f09780307b9);
#         }
#             geo_json_669234622ce7d9c155ea564ab4094f04_add({&quot;bbox&quot;: [-178.123152, 18.948267, 173.304726, 71.351633], &quot;features&quot;: [{&quot;bbox&quot;: [-88.471115, 30.247195, -84.889196, 35.00118], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-8

# %%
months_df = clean_power_outages_df.assign(
    **{
        'MONTH': clean_power_outages_df['OUTAGE.START.TIME'].dt.month
    }
)

months_df = months_df[months_df['OUTAGE.DURATION'].notna()]
months_df.head()
# Out:
#   U.S._STATE POSTAL.CODE NERC.REGION      CLIMATE.REGION ANOMALY.LEVEL  \
# 0  Minnesota          MN         MRO  East North Central          -0.3
# 1  Minnesota          MN         MRO  East North Central          -0.1
# 2  Minnesota          MN         MRO  East North Central          -1.5
# 3  Minnesota          MN         MRO  East North Central          -0.1
# 4  Minnesota          MN         MRO  East North Central           1.2
#
#     OUTAGE.START.TIME OUTAGE.RESTORATION.TIME      CAUSE.CATEGORY  \
# 0 2011-07-01 17:00:00     2011-07-03 20:00:00      severe weather
# 1 2014-05-11 18:38:00     2014-05-11 18:39:00  intentional attack
# 2 2010-10-26 20:00:00     2010-10-28 22:00:00      severe weather
# 3 2012-06-19 04:30:00     2012-06-20 23:00:00      severe weather
# 4 2015-07-18 02:00:00     2015-07-19 07:00:00      severe weather
#
#   OUTAGE.DURATION DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  RES.CUSTOMERS  \
# 0            51.0            NaN             70000.0      2308736.0
# 1        0.016667            NaN                 NaN      2345860.0
# 2            50.0            NaN             70000.0      2300291.0
# 3            42.5            NaN             68200.0      2317336.0
# 4            29.0            250            250000.0      2374674.0
#
#    COM.CUSTOMERS  IND.CUSTOMERS  TOTAL.CUSTOMERS  MONTH
# 0       276286.0        10673.0        2595696.0    7.0
# 1       284978.0         9898.0        2640737.0    5.0
# 2       276463.0        10150.0        2586905.0   10.0
# 3       278466.0        11010.0        2606813.0    6.0
# 4       289044.0         9812.0        2673531.0    7.0

# %%
lower_bound = np.quantile(months_df['OUTAGE.DURATION'], 0.75)
major_outages = months_df.loc[months_df['OUTAGE.DURATION'] >= lower_bound].groupby('U.S._STATE')['OUTAGE.DURATION'].count().to_frame()
major_outages.reset_index(inplace=True)
major_outages.columns = ['U.S State', 'Major Outages']

new_usa_map = folium.Map(location=[40, -95], zoom_start=4)
folium.Choropleth(
    geo_data=geojson_data,
    data=major_outages,
    columns=['U.S State', 'Major Outages'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Number of Major Outages',
).add_to(new_usa_map)

folium.LayerControl().add_to(new_usa_map)
new_usa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16c1120ca99a9441cc01cda61577a96e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16c1120ca99a9441cc01cda61577a96e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16c1120ca99a9441cc01cda61577a96e = L.map(
#                 &quot;map_16c1120ca99a9441cc01cda61577a96e&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc8599f8c5d3c21ac185af14fcf4e517 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_16c1120ca99a9441cc01cda61577a96e);
#
#
#             var choropleth_68a8e68c823269f76274c1557c247d8a = L.featureGroup(
#                 {}
#             ).addTo(map_16c1120ca99a9441cc01cda61577a96e);
#
#
#         function geo_json_2da351759e7a5c554d7a60d9f5c51815_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;23&quot;: case &quot;25&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;30&quot;: case &quot;33&quot;: case &quot;38&quot;: case &quot;40&quot;: case &quot;44&quot;: case &quot;49&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;37&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;8&quot;: case &quot;13&quot;: case &quot;19&quot;: case &quot;29&quot;: case &quot;34&quot;: case &quot;46&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2da351759e7a5c554d7a60d9f5c51815_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2da351759e7a5c554d7a60d9f5c51815 = L.geoJson(null, {
#                 onEachFeature: geo_json_2da351759e7a5c554d7a60d9f5c51815_onEachFeature,
#
#                 style: geo_json_2da351759e7a5c554d7a60d9f5c51815_styler,
#         });
#
#         function geo_json_2da351759e7a5c554d7a60d9f5c51815_add (data) {
#             geo_json_2da351759e7a5c554d7a60d9f5c51815
#                 .addData(data)
#                 .addTo(choropleth_68a8e68c823269f76274c1557c247d8a);
#         }
#             geo_json_2da351759e7a5c554d7a60d9f5c51815_add({&quot;bbox&quot;: [-178.123152, 18.948267, 173.304726, 71.351633], &quot;features&quot;: [{&quot;bbox&quot;: [-88.471115, 30.247195, -84.889196, 35.00118], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;id&quot;: &quot;AL&quot;, &quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&q

# %% [markdown]
# ## Interesting Aggregates

# %%
pd.pivot_table(
    clean_power_outages_df, 'OUTAGE.DURATION',
    'CLIMATE.REGION', 'CAUSE.CATEGORY', 'mean'
)
# Out:
# CAUSE.CATEGORY      equipment failure  fuel supply emergency  \
# CLIMATE.REGION
# Central                      5.366667             167.254167
# East North Central         440.588889             566.187500
# Northeast                    3.596667             243.826190
# Northwest                   11.700000               0.016667
# South                        4.929630             291.375000
# Southeast                    9.241667                    NaN
# Southwest                    1.896667               1.266667
# West                         8.746825             102.576667
# West North Central           1.016667                    NaN
#
# CAUSE.CATEGORY      intentional attack  islanding  public appeal  \
# CLIMATE.REGION
# Central                       5.767647   2.088889      23.500000
# East North Central           39.600833   0.016667      12.216667
# Northeast                     3.266412  14.683333      44.250000
# Northwest                     6.230196   1.222222      14.966667
# South                         5.426786   8.225000      19.399603
# Southeast                     8.411111        NaN      47.756667
# Southwest                     4.427869   0.033333      37.916667
# West                         14.294624   3.580952      33.801852
# West North Central            0.391667   1.136667       7.325000
#
# CAUSE.CATEGORY      severe weather  system operability disruption
# CLIMATE.REGION
# Central                  54.166792                      44.920000
# East North Central       73.913622                      43.500000
# Northeast                73.831714                      12.891667
# Northwest                80.633333                       2.350000
# South                    73.189151                      14.434568
# Southeast                44.376006                       2.821875
# Southwest               192.881667                       5.487037
# West                     48.806219                       6.061111
# West North Central       40.708333                            NaN

# %% [markdown]
# ### Assessment of Missingness

# %% [markdown]
# ## Missingness Dependency

# %%
state_dist = clean_power_outages_df.assign(**{
    'CLIMATE.REGION.MISSING': clean_power_outages_df['CLIMATE.REGION'].isna()
}).pivot_table(
    index='U.S._STATE', columns='CLIMATE.REGION.MISSING', aggfunc='size'
).replace(np.NaN, 0, inplace=False)

state_dist.columns = ['climate_region_missing = false', 'climate_region_missing = true']
state_dist = state_dist / state_dist.sum()
state_dist.head()
# Out:
#             climate_region_missing = false  climate_region_missing = true
# U.S._STATE
# Alabama                           0.003927                       0.000000
# Alaska                            0.000000                       0.166667
# Arizona                           0.018325                       0.000000
# Arkansas                          0.016361                       0.000000
# California                        0.137435                       0.000000

# %%
fig = state_dist.plot(kind='barh', title='State by Climate Region Missingness', barmode='group')
fig

# %%
fig.write_html('state_climate_missing.html')

# %%
repitions = 500
shuffled = clean_power_outages_df.copy(deep=True)
shuffled['CLIMATE.REGION.MISSING'] = shuffled['CLIMATE.REGION'].isna()
shuffled
# Out:
#         U.S._STATE POSTAL.CODE NERC.REGION      CLIMATE.REGION ANOMALY.LEVEL  \
# 0        Minnesota          MN         MRO  East North Central          -0.3
# 1        Minnesota          MN         MRO  East North Central          -0.1
# 2        Minnesota          MN         MRO  East North Central          -1.5
# 3        Minnesota          MN         MRO  East North Central          -0.1
# 4        Minnesota          MN         MRO  East North Central           1.2
# ...            ...         ...         ...                 ...           ...
# 1529  North Dakota          ND         MRO  West North Central          -0.9
# 1530  North Dakota          ND         MRO  West North Central           NaN
# 1531  South Dakota          SD         RFC  West North Central           0.5
# 1532  South Dakota          SD         MRO  West North Central           0.5
# 1533        Alaska          AK        ASCC                 NaN           NaN
#
#        OUTAGE.START.TIME OUTAGE.RESTORATION.TIME         CAUSE.CATEGORY  \
# 0    2011-07-01 17:00:00     2011-07-03 20:00:00         severe weather
# 1    2014-05-11 18:38:00     2014-05-11 18:39:00     intentional attack
# 2    2010-10-26 20:00:00     2010-10-28 22:00:00         severe weather
# 3    2012-06-19 04:30:00     2012-06-20 23:00:00         severe weather
# 4    2015-07-18 02:00:00     2015-07-19 07:00:00         severe weather
# ...                  ...                     ...                    ...
# 1529 2011-12-06 08:00:00     2011-12-06 20:00:00          public appeal
# 1530                 NaT                     NaT  fuel supply emergency
# 1531 2009-08-29 22:54:00     2009-08-29 23:53:00              islanding
# 1532 2009-08-29 11:00:00     2009-08-29 14:01:00              islanding
# 1533                 NaT                     NaT      equipment failure
#
#      OUTAGE.DURATION DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  RES.CUSTOMERS  \
# 0               51.0            NaN             70000.0      2308736.0
# 1           0.016667            NaN                 NaN      2345860.0
# 2               50.0            NaN             70000.0      2300291.0
# 3               42.5            NaN             68200.0      2317336.0
# 4               29.0            250            250000.0      2374674.0
# ...              ...            ...                 ...            ...
# 1529            12.0            155             34500.0       330738.0
# 1530             NaN           1650                 NaN       309997.0
# 1531        0.983333             84                 NaN       367206.0
# 1532        3.016667            373                 NaN       367206.0
# 1533             NaN             35             14273.0       230534.0
#
#       COM.CUSTOMERS  IND.CUSTOMERS  TOTAL.CUSTOMERS  CLIMATE.REGION.MISSING
# 0          276286.0        10673.0        2595696.0                   False
# 1          284978.0         9898.0        2640737.0                   False
# 2          276463.0        10150.0        2586905.0                   False
# 3          278466.0        11010.0        2606813.0                   False
# 4          289044.0         9812.0        2673531.0                   False
# ...             ...            ...              ...                     ...
# 1529        60017.0         3639.0         394394.0                   False
# 1530        53709.0         2331.0         366037.0                   False
# 1531        65971.0         3052.0         436229.0                   False
# 1532        65971.0         3052.0         436229.0                   False
# 1533        38074.0          854.0         273530.0                    True
#
# [1534 rows x 16 columns]

# %%
tvds = []
for _ in range(repitions):
    shuffled['U.S._STATE'] = np.random.permutation(shuffled['U.S._STATE'])
    pivoted = shuffled.pivot_table(
        index='U.S._STATE', columns='CLIMATE.REGION.MISSING', aggfunc='size'
    ).apply(lambda x: x / x.sum()).replace(np.NaN, 0, inplace=False)

    tvd = pivoted.diff(axis=1).iloc[:, -1].abs().sum() / 2
    tvds.append(tvd)

# %%
observed_tvd = state_dist.diff(axis=1).iloc[:, -1].abs().sum() / 2
observed_tvd
# Out:
# 1.0

# %%
fig = px.histogram(pd.DataFrame(tvds), x=0, nbins=50, histnorm='probability', 
                   title='Emp Dist of TVD')
fig.add_vline(x=observed_tvd, line_color='red')
fig

# %%
p_value = np.mean(np.array(tvds) >= observed_tvd)
p_value
# Out:
# 0.0

# %% [markdown]
# Reject null and say that data too extreme to say missing climate region data with respect to US State is MCAR

# %%
cause_dist = clean_power_outages_df.assign(**{
    'outage_missing': clean_power_outages_df['OUTAGE.START.TIME'].isna()
}).pivot_table(
    index='CAUSE.CATEGORY', columns='outage_missing', aggfunc='size'
).replace(np.NaN, 0, inplace=False)

cause_dist.columns = ['outage_missing = false', 'outage_missing = true']
cause_dist = cause_dist / cause_dist.sum()
cause_dist.head()
# Out:
#                        outage_missing = false  outage_missing = true
# CAUSE.CATEGORY
# equipment failure                    0.037377               0.333333
# fuel supply emergency                0.032787               0.111111
# intentional attack                   0.274098               0.000000
# islanding                            0.030164               0.000000
# public appeal                        0.045246               0.000000

# %%
fig = cause_dist.plot(kind='barh', title='Cause Category by Demand Loss Missingness', barmode='group')
fig

# %%
repitions = 500
shuffled = clean_power_outages_df.copy(deep=True)
shuffled['outage_missing'] = shuffled['OUTAGE.START.TIME'].isna()
shuffled.head()
# Out:
#   U.S._STATE POSTAL.CODE NERC.REGION      CLIMATE.REGION ANOMALY.LEVEL  \
# 0  Minnesota          MN         MRO  East North Central          -0.3
# 1  Minnesota          MN         MRO  East North Central          -0.1
# 2  Minnesota          MN         MRO  East North Central          -1.5
# 3  Minnesota          MN         MRO  East North Central          -0.1
# 4  Minnesota          MN         MRO  East North Central           1.2
#
#     OUTAGE.START.TIME OUTAGE.RESTORATION.TIME      CAUSE.CATEGORY  \
# 0 2011-07-01 17:00:00     2011-07-03 20:00:00      severe weather
# 1 2014-05-11 18:38:00     2014-05-11 18:39:00  intentional attack
# 2 2010-10-26 20:00:00     2010-10-28 22:00:00      severe weather
# 3 2012-06-19 04:30:00     2012-06-20 23:00:00      severe weather
# 4 2015-07-18 02:00:00     2015-07-19 07:00:00      severe weather
#
#   OUTAGE.DURATION DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  RES.CUSTOMERS  \
# 0            51.0            NaN             70000.0      2308736.0
# 1        0.016667            NaN                 NaN      2345860.0
# 2            50.0            NaN             70000.0      2300291.0
# 3            42.5            NaN             68200.0      2317336.0
# 4            29.0            250            250000.0      2374674.0
#
#    COM.CUSTOMERS  IND.CUSTOMERS  TOTAL.CUSTOMERS  outage_missing
# 0       276286.0        10673.0        2595696.0           False
# 1       284978.0         9898.0        2640737.0           False
# 2       276463.0        10150.0        2586905.0           False
# 3       278466.0        11010.0        2606813.0           False
# 4       289044.0         9812.0        2673531.0           False

# %%
tvds = []
for _ in range(repitions):
    shuffled['CAUSE.CATEGORY'] = np.random.permutation(shuffled['CAUSE.CATEGORY'])
    pivoted = shuffled.pivot_table(
        index='CAUSE.CATEGORY', columns='outage_missing', aggfunc='size'
    ).apply(lambda x: x / x.sum()).replace(np.NaN, 0, inplace=False)

    tvd = pivoted.diff(axis=1).iloc[:, -1].abs().sum() / 2
    tvds.append(tvd)

# %%
observed_tvd = cause_dist.diff(axis=1).iloc[:, -1].abs().sum() / 2
observed_tvd
# Out:
# 0.40276867030965396

# %%
fig = px.histogram(pd.DataFrame(tvds), x=0, nbins=50, histnorm='probability', 
                   title='Emp Dist of TVD')
fig.add_vline(x=observed_tvd, line_color='red')
fig

# %%
p_value = np.mean(np.array(tvds) >= observed_tvd)
p_value
# Out:
# 0.058

# %% [markdown]
# We fail to reject null. Data is not extreme enough to say data is not MCAR. Therefore, we support the null hypothesis.

# %% [markdown]
# ### Hypothesis Testing

# %%
clean_power_outages_df
# Out:
#         U.S._STATE POSTAL.CODE NERC.REGION      CLIMATE.REGION ANOMALY.LEVEL  \
# 0        Minnesota          MN         MRO  East North Central          -0.3
# 1        Minnesota          MN         MRO  East North Central          -0.1
# 2        Minnesota          MN         MRO  East North Central          -1.5
# 3        Minnesota          MN         MRO  East North Central          -0.1
# 4        Minnesota          MN         MRO  East North Central           1.2
# ...            ...         ...         ...                 ...           ...
# 1529  North Dakota          ND         MRO  West North Central          -0.9
# 1530  North Dakota          ND         MRO  West North Central           NaN
# 1531  South Dakota          SD         RFC  West North Central           0.5
# 1532  South Dakota          SD         MRO  West North Central           0.5
# 1533        Alaska          AK        ASCC                 NaN           NaN
#
#        OUTAGE.START.TIME OUTAGE.RESTORATION.TIME         CAUSE.CATEGORY  \
# 0    2011-07-01 17:00:00     2011-07-03 20:00:00         severe weather
# 1    2014-05-11 18:38:00     2014-05-11 18:39:00     intentional attack
# 2    2010-10-26 20:00:00     2010-10-28 22:00:00         severe weather
# 3    2012-06-19 04:30:00     2012-06-20 23:00:00         severe weather
# 4    2015-07-18 02:00:00     2015-07-19 07:00:00         severe weather
# ...                  ...                     ...                    ...
# 1529 2011-12-06 08:00:00     2011-12-06 20:00:00          public appeal
# 1530                 NaT                     NaT  fuel supply emergency
# 1531 2009-08-29 22:54:00     2009-08-29 23:53:00              islanding
# 1532 2009-08-29 11:00:00     2009-08-29 14:01:00              islanding
# 1533                 NaT                     NaT      equipment failure
#
#      OUTAGE.DURATION DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  RES.CUSTOMERS  \
# 0               51.0            NaN             70000.0      2308736.0
# 1           0.016667            NaN                 NaN      2345860.0
# 2               50.0            NaN             70000.0      2300291.0
# 3               42.5            NaN             68200.0      2317336.0
# 4               29.0            250            250000.0      2374674.0
# ...              ...            ...                 ...            ...
# 1529            12.0            155             34500.0       330738.0
# 1530             NaN           1650                 NaN       309997.0
# 1531        0.983333             84                 NaN       367206.0
# 1532        3.016667            373                 NaN       367206.0
# 1533             NaN             35             14273.0       230534.0
#
#       COM.CUSTOMERS  IND.CUSTOMERS  TOTAL.CUSTOMERS
# 0          276286.0        10673.0        2595696.0
# 1          284978.0         9898.0        2640737.0
# 2          276463.0        10150.0        2586905.0
# 3          278466.0        11010.0        2606813.0
# 4          289044.0         9812.0        2673531.0
# ...             ...            ...              ...
# 1529        60017.0         3639.0         394394.0
# 1530        53709.0         2331.0         366037.0
# 1531        65971.0         3052.0         436229.0
# 1532        65971.0         3052.0         436229.0
# 1533        38074.0          854.0         273530.0
#
# [1534 rows x 15 columns]

# %%
cleaned_outage_duration = clean_power_outages_df[clean_power_outages_df['OUTAGE.DURATION'].notna()]
cleaned_major_outages = cleaned_outage_duration.loc[cleaned_outage_duration['OUTAGE.DURATION'] >= np.quantile(cleaned_outage_duration['OUTAGE.DURATION'], 0.75)].\
groupby('NERC.REGION')['OUTAGE.DURATION'].count()

print(cleaned_major_outages.sum())

cleaned_major_outages = cleaned_major_outages / cleaned_major_outages.sum()
cleaned_major_outages
# Out:
# 377
# NERC.REGION
# ECAR    0.076923
# FRCC    0.045093
# MRO     0.034483
# NPCC    0.122016
# RFC     0.416446
# SERC    0.074271
# SPP     0.039788
# TRE     0.066313
# WECC    0.124668
# Name: OUTAGE.DURATION, dtype: float64

# %% [markdown]
# Null Hypothesis: There is no difference in proportions of major power outages between NERC regions.

# %% [markdown]
# Alternative Hypothesis: There is a difference in proportions of major power outages between NERC regions.

# %% [markdown]
# We define a major power outage as being the 75th percentile or above in outage duration.

# %%
hypothesis_df = cleaned_major_outages.to_frame()
hypothesis_df['Expected Proportions'] = [(1 / hypothesis_df.shape[0]) for _ in range(hypothesis_df.shape[0])]
hypothesis_df.columns = ['Observed Proportions', 'Expected Proportions']
hypothesis_df
# Out:
#              Observed Proportions  Expected Proportions
# NERC.REGION
# ECAR                     0.076923              0.111111
# FRCC                     0.045093              0.111111
# MRO                      0.034483              0.111111
# NPCC                     0.122016              0.111111
# RFC                      0.416446              0.111111
# SERC                     0.074271              0.111111
# SPP                      0.039788              0.111111
# TRE                      0.066313              0.111111
# WECC                     0.124668              0.111111

# %%
hypothesis_df.plot(kind='barh', title='Distribution of Proportions of Major Outages Across NERC Regions', barmode='group')

# %%
observed_tvd = np.sum(np.abs(hypothesis_df['Observed Proportions'] - hypothesis_df['Expected Proportions'])) / 2
observed_tvd
# Out:
# 0.32979664014146765

# %%
N_Outages = 377
draws = np.random.multinomial(N_Outages, hypothesis_df['Expected Proportions'], size=100_000) / N_Outages
draws
# Out:
# array([[0.09549072, 0.10079576, 0.09549072, ..., 0.14058355, 0.12466844,
#         0.12201592],
#        [0.12997347, 0.0928382 , 0.11405836, ..., 0.10079576, 0.1061008 ,
#         0.08753316],
#        [0.0928382 , 0.13793103, 0.15384615, ..., 0.10079576, 0.10079576,
#         0.09018568],
#        ...,
#        [0.10875332, 0.11405836, 0.09814324, ..., 0.12997347, 0.13793103,
#         0.0795756 ],
#        [0.10344828, 0.1193634 , 0.10875332, ..., 0.12201592, 0.11671088,
#         0.10079576],
#        [0.12732095, 0.10079576, 0.09814324, ..., 0.09549072, 0.12201592,
#         0.1061008 ]])

# %%
all_tvds = np.sum(np.abs(draws - hypothesis_df['Expected Proportions'].to_numpy()), axis=1) / 2
all_tvds
# Out:
# array([0.0542293 , 0.05717654, 0.07810197, ..., 0.06248158, 0.04656646,
#        0.05688182])

# %%
fig = px.histogram(pd.DataFrame(all_tvds), x=0, nbins=50, histnorm='probability', 
                   title='Empirical Distribution of the TVD')
fig.add_vline(x=observed_tvd, line_color='red')
fig

# %%
p_value = (np.array(all_tvds) >= observed_tvd).mean()
p_value
# Out:
# 0.0

# %% [markdown]
# Conclusion: We reject the null hypothesis and support the claim that the proportion of major outages is different across the different NERC regions in some way.

# %% [markdown]
# This was relatively expected just from viewing the data in the grouped bar chart but our p value confirms our results.
